# %% [markdown]
# # Remaining issues

# %% [markdown]
# ## Only a subset of mathematic functions
#
# Let's take this example : we want to compute the total energy `e` of an electron whose linear momentum `p` is known. We can deduce it from the equality `e^2 = m^2*c^4 + p^2*c^2`, with `c` the speed of light and `m` the mass of the electron.

# %%
# %%file tmp.remaining-issues.cpp
#
# #include <iostream>
# #include "phys/units/io.hpp"
# #include "phys/units/quantity.hpp"
#
# using namespace phys::units ;
# using namespace phys::units::io ;
# using namespace phys::units::literals ;
#
# int main()
#  {
#   constexpr auto m = 9.109e-31_kg ;
#   constexpr auto c = 299792458_m/second ;
#   constexpr auto p = 2e-22_kg*meter/second ;
#
#   auto e = sqrt(square(m)*nth_power<4>(c)+square(p)*square(c)) ;
#
#   std::cout << e << std::endl ;
#  }
# Out:
# Overwriting tmp.remaining-issues.cpp

# %%
# !rm -f tmp.remaining-issues.exe && g++ -I. -std=c++17 tmp.remaining-issues.cpp -o tmp.remaining-issues.exe

# %%
# !./tmp.remaining-issues.exe
# Out:
# 1.01476e-13 J

# %% [markdown]
# We were not able to use `std::pow`, which would have not correctly handle the unit of `c`.

# %% [markdown]
# We were not able to benefit for the `constexpr` of `e`,  because the `sqrt` function used is not provided by the standard library, but is an alternative implementation from PhysUnits, which can handle units, but is not a `constexpr`.

# %% [markdown]
# The use of a library of units tends to **limit us to the numerical functions provided by this library**, with their limitations.

# %% [markdown]
# ## Irrelevant internal reference unit
#
# Let's try our example with `float`.

# %%
# %%file tmp.remaining-issues.cpp
#
# #include <iostream>
#
# #include "phys/units/io.hpp"
# #include "phys/units/quantity.hpp"
#
# using namespace phys::units ;
# using namespace phys::units::io;
# using namespace phys::units::literals ;
# using momentum_d = dimensions< 1, 1, -1 > ;
#
# int main()
#  {
#   constexpr quantity<mass_d,float> m = 9.109e-31_kg ;
#   constexpr quantity<speed_d,float> c = 299792458_m/second ;
#   constexpr quantity<momentum_d,float> p = m*0.75*c ;
#
#   auto e = sqrt(square(m)*nth_power<4>(c)+square(p)*square(c)) ;
#
#   std::cout << e << std::endl ;
#  }
# Out:
# Overwriting tmp.remaining-issues.cpp

# %%
# !rm -f tmp.remaining-issues.exe && g++ -I. -std=c++17 tmp.remaining-issues.cpp -o tmp.remaining-issues.exe

# %%
# !./tmp.remaining-issues.exe
# Out:
# 6.14677e-14 J

# %% [markdown]
# **The result if very wrong**. However, we can prove that this computation can be done with simple precision, provided we express our variables in a unit which is close to the scale of the problem, which is not the case of `kg` above, used internally by PhysUnits.
#
# Below, the mass and linear momentum have been shift by `1e27`, any computation is enforced in `float`, and the result is a lot more acceptable.

# %%
# %%file tmp.remaining-issues.cpp
#
# #include <iostream>
# #include <cmath>
#
# int main()
#  {
#   constexpr float m = 0.0009109 ;
#   constexpr float c = 299792458 ;
#   constexpr float p = m*0.75f*c ;
#
#   constexpr float m2 = m*m ;
#   constexpr float c2 = c*c ;
#   constexpr float c4 = c2*c2 ;
#   constexpr float p2 = p*p ;
#   constexpr float e = sqrt(m2*c4+p2*c2) ;
#
#   std::cout << e*1e-27 << std::endl ;
#  }
# Out:
# Writing tmp.remaining-issues.cpp

# %%
# !rm -f tmp.remaining-issues.exe && g++ -I. -std=c++17 tmp.remaining-issues.cpp -o tmp.remaining-issues.exe

# %%
# !./tmp.remaining-issues.exe
# Out:
# 1.02335e-13

# %% [markdown]
# In the domain of infinitely small and infinitely large, it is aberrant to store values in seconds, meters, kilograms, etc. **The units library must let you control the unit used for internal storage**, or you may suffer a huge loss of precision. About this topic, Martin Moene (the author of PhysUnits) indicates the work of Tony Pilz (which I did not explore yet) :
# * ScaledValue : https://github.com/tonypilz/ScaledValue
# * Units : https://github.com/tonypilz/units

# %% [markdown]
# ## Libraries of linear algebra
#
# In scientific computing, we often use a lot of matrice computation, and deeply rely on libraries like Eigen... Can we make Eigen uses units provided by PhysUnits ? Let's try to compute the linear momentum of our electron, but in 3D space, with x/y/z coordinates.

# %%
# %%file tmp.remaining-issues.h
#
# #include <iostream>
#
# #include "phys/units/io.hpp"
# #include "phys/units/quantity.hpp"
# #include "Eigen/Dense"
#
# using namespace phys::units ;
# using namespace phys::units::io;
# using namespace phys::units::literals ;
#
# using momentum_d = dimensions< 1, 1, -1 > ;
#
# using Speed = quantity<speed_d> ;
# using Momentum = quantity<momentum_d> ;
#
# using Speed3d = Eigen::Matrix<Speed,3,1> ;
# using Momentum3d = Eigen::Matrix<Momentum,3,1> ;
# Out:
# Writing tmp.remaining-issues.h

# %%
# %%file tmp.remaining-issues.cpp
#
# #include "tmp.remaining-issues.h"
#
# int main()
#  {
#   constexpr quantity<mass_d> m = 0.0009109_yg ;
#   constexpr quantity<speed_d> c = 299792458_m/second ;
#
#   Speed speed_x = 0.75/sqrt(3.)*c ;
#   Speed speed_y = speed_x, speed_z = speed_x ;
#   Speed3d speed(speed_x,speed_y,speed_z) ;
#
#   Momentum3d momentum = m*speed ;
#   Momentum p = momentum.norm()*kilogram*meter/second ;
#   auto e = sqrt(square(m)*nth_power<4>(c)+square(p)*square(c)) ;
#   std::cout << speed << std::endl ;
#  }
# Out:
# Overwriting tmp.remaining-issues.cpp

# %%
# !rm -f tmp.remaining-issues.exe && g++ -I/opt/miniconda3/include/eigen3/ -I. -std=c++17 tmp.remaining-issues.cpp -o tmp.remaining-issues.exe
# Out:
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:263,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/arch/SSE/PacketMath.h:29:39: warning: ignoring attributes on template argument ‘__m128’ [-Wignored-attributes]
#    29 | template<> struct is_arithmetic<__m128>  { enum { value = true }; };
#       |                                       ^
# /opt/miniconda3/include/eigen3/Eigen/src/Core/arch/SSE/PacketMath.h:30:40: warning: ignoring attributes on template argument ‘__m128i’ [-Wignored-attributes]
#    30 | template<> struct is_arithmetic<__m128i> { enum { value = true }; };
#       |                                        ^
# /opt/miniconda3/include/eigen3/Eigen/src/Core/arch/SSE/PacketMath.h:31:40: warning: ignoring attributes on template argument ‘__m128d’ [-Wignored-attributes]
#    31 | template<> struct is_arithmetic<__m128d> { enum { value = true }; };
#       |                                        ^
# /opt/miniconda3/include/eigen3/Eigen/src/Core/arch/SSE/PacketMath.h:101:43: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4f’ {aka ‘__m128’} [-Wignored-attributes]
#   101 | template<> struct unpacket_traits<Packet4f> { typedef float  type; enum {size=4}; };
#       |                                           ^
# /opt/miniconda3/include/eigen3/Eigen/src/Core/arch/SSE/PacketMath.h:102:43: warning: ignoring attributes on template argument ‘Eigen::internal::Packet2d’ {aka ‘__m128d’} [-Wignored-attributes]
#   102 | template<> struct unpacket_traits<Packet2d> { typedef double type; enum {size=2}; };
#       |                                           ^
# /opt/miniconda3/include/eigen3/Eigen/src/Core/arch/SSE/PacketMath.h:103:43: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4i’ {aka ‘__m128i’} [-Wignored-attributes]
#   103 | template<> struct unpacket_traits<Packet4i> { typedef int    type; enum {size=4}; };
#       |                                           ^
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:263,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/arch/SSE/PacketMath.h:586:35: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4f’ {aka ‘__m128’} [-Wignored-attributes]
#   586 | struct palign_impl<Offset,Packet4f>
#       |                                   ^
# /opt/miniconda3/include/eigen3/Eigen/src/Core/arch/SSE/PacketMath.h:609:35: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4i’ {aka ‘__m128i’} [-Wignored-attributes]
#   609 | struct palign_impl<Offset,Packet4i>
#       |                                   ^
# /opt/miniconda3/include/eigen3/Eigen/src/Core/arch/SSE/PacketMath.h:632:35: warning: ignoring attributes on template argument ‘Eigen::internal::Packet2d’ {aka ‘__m128d’} [-Wignored-attributes]
#   632 | struct palign_impl<Offset,Packet2d>
#       |                                   ^
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:265,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/arch/SSE/Complex.h:211:63: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4f’ {aka ‘__m128’} [-Wignored-attributes]
#   211 | template<> struct conj_helper<Packet4f, Packet2cf, false,false>
#       |                                                               ^
# /opt/miniconda3/include/eigen3/Eigen/src/Core/arch/SSE/Complex.h:220:63: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4f’ {aka ‘__m128’} [-Wignored-attributes]
#   220 | template<> struct conj_helper<Packet2cf, Packet4f, false,false>
#       |                                                               ^
# /opt/miniconda3/include/eigen3/Eigen/src/Core/arch/SSE/Complex.h:407:63: warning: ignoring attributes on template argument ‘Eigen::internal::Packet2d’ {aka ‘__m128d’} [-Wignored-attributes]
#   407 | template<> struct conj_helper<Packet2d, Packet1cd, false,false>
#       |                                                               ^
# /opt/miniconda3/include/eigen3/Eigen/src/Core/arch/SSE/Complex.h:416:63: warning: ignoring attributes on template argument ‘Eigen::internal::Packet2d’ {aka ‘__m128d’} [-Wignored-attributes]
#   416 | template<> struct conj_helper<Packet1cd, Packet2d, false,false>
#       |                                                               ^
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:276,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/Functors.h:973:28: warning: ‘template<class _Operation> class std::binder2nd’ is deprecated: use 'std::bind' instead [-Wdeprecated-declarations]
#   973 | struct functor_traits<std::binder2nd<T> >
#       |                            ^~~~~~~~~
# In file included from /usr/local/include/c++/11.2.0/bits/stl_function.h:1407,
#                  from /usr/local/include/c++/11.2.0/string:48,
#                  from /usr/local/include/c++/11.2.0/bits/locale_classes.h:40,
#                  from /usr/local/include/c++/11.2.0/bits/ios_base.h:41,
#                  from /usr/local/include/c++/11.2.0/ios:42,
#                  from /usr/local/include/c++/11.2.0/ostream:38,
#                  from /usr/local/include/c++/11.2.0/iostream:39,
#                  from tmp.remaining-issues.h:2,
#                  from tmp.remaining-issues.cpp:2:
# /usr/local/include/c++/11.2.0/backward/binders.h:143:11: note: declared here
#   143 |     class binder2nd
#       |           ^~~~~~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:276,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/Functors.h:977:28: warning: ‘template<class _Operation> class std::binder1st’ is deprecated: use 'std::bind' instead [-Wdeprecated-declarations]
#   977 | struct functor_traits<std::binder1st<T> >
#       |                            ^~~~~~~~~
# In file included from /usr/local/include/c++/11.2.0/bits/stl_function.h:1407,
#                  from /usr/local/include/c++/11.2.0/string:48,
#                  from /usr/local/include/c++/11.2.0/bits/locale_classes.h:40,
#                  from /usr/local/include/c++/11.2.0/bits/ios_base.h:41,
#                  from /usr/local/include/c++/11.2.0/ios:42,
#                  from /usr/local/include/c++/11.2.0/ostream:38,
#                  from /usr/local/include/c++/11.2.0/iostream:39,
#                  from tmp.remaining-issues.h:2,
#                  from tmp.remaining-issues.cpp:2:
# /usr/local/include/c++/11.2.0/backward/binders.h:108:11: note: declared here
#   108 |     class binder1st
#       |           ^~~~~~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:277,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<float, 4, 1>, 0>’:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<float, 4, 1>, 1>’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<float, 4, 1>, 3>’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Matrix<float, 4, 1>, float, float, false>’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Matrix<float, 4, 1> >’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Matrix<float, 4, 1> >’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/PlainObjectBase.h:88:7:   required from ‘class Eigen::PlainObjectBase<Eigen::Matrix<float, 4, 1> >’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/Matrix.h:127:7:   required from ‘class Eigen::Matrix<float, 4, 1>’
# /opt/miniconda3/include/eigen3/Eigen/src/Geometry/Quaternion.h:282:16:   required from ‘class Eigen::Quaternion<float>’
# /opt/miniconda3/include/eigen3/Eigen/src/Geometry/arch/Geometry_SSE.h:22:3:   required from here
# /opt/miniconda3/include/eigen3/Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<float>::type’ {aka ‘__m128’} [-Wignored-attributes]
#    56 |                      >::type PacketReturnType;
#       |                              ^~~~~~~~~~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 4, 1>, 0>’:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 4, 1>, 1>’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 4, 1>, 3>’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Matrix<double, 4, 1>, double, double, false>’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Matrix<double, 4, 1> >’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Matrix<double, 4, 1> >’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/PlainObjectBase.h:88:7:   required from ‘class Eigen::PlainObjectBase<Eigen::Matrix<double, 4, 1> >’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/Matrix.h:127:7:   required from ‘class Eigen::Matrix<double, 4, 1>’
# /opt/miniconda3/include/eigen3/Eigen/src/Geometry/Quaternion.h:282:16:   required from ‘class Eigen::Quaternion<double>’
# /opt/miniconda3/include/eigen3/Eigen/src/Geometry/arch/Geometry_SSE.h:63:3:   required from here
# /opt/miniconda3/include/eigen3/Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# tmp.remaining-issues.cpp: In function ‘int main()’:
# tmp.remaining-issues.cpp:13:26: error: no match for ‘operator*’ (operand types are ‘const phys::units::quantity<phys::units::dimensions<0, 1, 0, 0, 0, 0, 0> >’ and ‘Speed3d’ {aka ‘Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>’})
#    13 |   Momentum3d momentum = m*speed ;
#       |                         ~^~~~~~
#       |                         | |
#       |                         | Speed3d {aka Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>}
#       |                         const phys::units::quantity<phys::units::dimensions<0, 1, 0, 0, 0, 0, 0> >
# In file included from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# ./phys/units/quantity.hpp:550:1: note: candidate: ‘template<class D, class X, class Y> constexpr phys::units::quantity<D, decltype ((declval<X>() * declval<Y>()))> phys::units::operator*(const phys::units::quantity<D, T>&, const Y&)’
#   550 | operator*( quantity<D, X> const & x, Y const & y )
#       | ^~~~~~~~
# ./phys/units/quantity.hpp:550:1: note:   template argument deduction/substitution failed:
# ./phys/units/quantity.hpp: In substitution of ‘template<class D, class X, class Y> constexpr phys::units::quantity<D, decltype ((declval<X>() * declval<Y>()))> phys::units::operator*(const phys::units::quantity<D, T>&, const Y&) [with D = phys::units::dimensions<0, 1, 0, 0, 0, 0, 0>; X = double; Y = Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>]’:
# tmp.remaining-issues.cpp:13:27:   required from here
# ./phys/units/quantity.hpp:136:48: error: no match for ‘operator*’ (operand types are ‘double’ and ‘Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>’)
#   136 | using PromoteMul = decltype( std::declval<X>() * std::declval<Y>() );
#       |                              ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~
# ./phys/units/quantity.hpp:550:1: note: candidate: ‘template<class D, class X, class Y> constexpr phys::units::quantity<D, decltype ((declval<X>() * declval<Y>()))> phys::units::operator*(const phys::units::quantity<D, T>&, const Y&)’
#   550 | operator*( quantity<D, X> const & x, Y const & y )
#       | ^~~~~~~~
# ./phys/units/quantity.hpp:550:1: note:   template argument deduction/substitution failed:
# ./phys/units/quantity.hpp:136:48: note:   mismatched types ‘const phys::units::quantity<D, T>’ and ‘double’
#   136 | using PromoteMul = decltype( std::declval<X>() * std::declval<Y>() );
#       |                              ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~
# ./phys/units/quantity.hpp:559:1: note: candidate: ‘template<class D, class X, class Y> constexpr phys::units::quantity<D, decltype ((declval<X>() * declval<Y>()))> phys::units::operator*(const X&, const phys::units::quantity<D, Y>&)’
#   559 | operator*( X const & x, quantity<D, Y> const & y )
#       | ^~~~~~~~
# ./phys/units/quantity.hpp:559:1: note:   template argument deduction/substitution failed:
# ./phys/units/quantity.hpp:136:48: note:   ‘Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>’ is not derived from ‘const phys::units::quantity<D, Y>’
#   136 | using PromoteMul = decltype( std::declval<X>() * std::declval<Y>() );
#       |                              ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~
# ./phys/units/quantity.hpp:568:1: note: candidate: ‘template<class DX, class DY, class X, class Y> constexpr phys::units::detail::Product<DX, DY, X, Y> phys::units::operator*(const phys::units::quantity<D, Y>&, const phys::units::quantity<DY, Y>&)’
#   568 | operator*( quantity<DX, X> const & lhs, quantity< DY, Y > const & rhs )
#       | ^~~~~~~~
# ./phys/units/quantity.hpp:568:1: note:   template argument deduction/substitution failed:
# ./phys/units/quantity.hpp:136:48: note:   mismatched types ‘const phys::units::quantity<D, Y>’ and ‘double’
#   136 | using PromoteMul = decltype( std::declval<X>() * std::declval<Y>() );
#       |                              ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:313,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/PermutationMatrix.h:539:1: note: candidate: ‘template<class Derived, class PermutationDerived> const Eigen::internal::permut_matrix_product_retval<PermutationDerived, Derived, 2> Eigen::operator*(const Eigen::MatrixBase<Derived>&, const Eigen::PermutationBase<PermutationDerived>&)’
#   539 | operator*(const MatrixBase<Derived>& matrix,
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/PermutationMatrix.h:539:1: note:   template argument deduction/substitution failed:
# In file included from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# ./phys/units/quantity.hpp:136:48: note:   mismatched types ‘const Eigen::MatrixBase<Derived>’ and ‘double’
#   136 | using PromoteMul = decltype( std::declval<X>() * std::declval<Y>() );
#       |                              ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:313,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/PermutationMatrix.h:552:1: note: candidate: ‘template<class Derived, class PermutationDerived> const Eigen::internal::permut_matrix_product_retval<PermutationDerived, Derived, 1> Eigen::operator*(const Eigen::PermutationBase<PermutationDerived>&, const Eigen::MatrixBase<Derived>&)’
#   552 | operator*(const PermutationBase<PermutationDerived> &permutation,
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/PermutationMatrix.h:552:1: note:   template argument deduction/substitution failed:
# In file included from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# ./phys/units/quantity.hpp:136:48: note:   mismatched types ‘const Eigen::PermutationBase<PermutationDerived>’ and ‘double’
#   136 | using PromoteMul = decltype( std::declval<X>() * std::declval<Y>() );
#       |                              ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:314,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/Transpositions.h:331:1: note: candidate: ‘template<class Derived, class TranspositionsDerived> const Eigen::internal::transposition_matrix_product_retval<TranspositionsDerived, Derived, 2> Eigen::operator*(const Eigen::MatrixBase<Derived>&, const Eigen::TranspositionsBase<TranspositionsDerived>&)’
#   331 | operator*(const MatrixBase<Derived>& matrix,
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/Transpositions.h:331:1: note:   template argument deduction/substitution failed:
# In file included from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# ./phys/units/quantity.hpp:136:48: note:   mismatched types ‘const Eigen::MatrixBase<Derived>’ and ‘double’
#   136 | using PromoteMul = decltype( std::declval<X>() * std::declval<Y>() );
#       |                              ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:314,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/Transpositions.h:344:1: note: candidate: ‘template<class Derived, class TranspositionDerived> const Eigen::internal::transposition_matrix_product_retval<TranspositionDerived, Derived, 1> Eigen::operator*(const Eigen::TranspositionsBase<TranspositionsDerived>&, const Eigen::MatrixBase<Derived>&)’
#   344 | operator*(const TranspositionsBase<TranspositionDerived> &transpositions,
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/Transpositions.h:344:1: note:   template argument deduction/substitution failed:
# In file included from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# ./phys/units/quantity.hpp:136:48: note:   mismatched types ‘const Eigen::TranspositionsBase<TranspositionsDerived>’ and ‘double’
#   136 | using PromoteMul = decltype( std::declval<X>() * std::declval<Y>() );
#       |                              ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:322,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/ProductBase.h:210:1: note: candidate: ‘template<class Derived, class Lhs, class Rhs> const Eigen::ScaledProduct<Derived> Eigen::operator*(const Eigen::ProductBase<Derived, _Lhs, _Rhs>&, const typename Derived::Scalar&)’
#   210 | operator*(const ProductBase<Derived,Lhs,Rhs>& prod, const typename Derived::Scalar& x)
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/ProductBase.h:210:1: note:   template argument deduction/substitution failed:
# In file included from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# ./phys/units/quantity.hpp:136:48: note:   mismatched types ‘const Eigen::ProductBase<Derived, _Lhs, _Rhs>’ and ‘double’
#   136 | using PromoteMul = decltype( std::declval<X>() * std::declval<Y>() );
#       |                              ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:322,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/ProductBase.h:216:1: note: candidate: ‘template<class Derived, class Lhs, class Rhs> typename Eigen::internal::enable_if<(! Eigen::internal::is_same<typename Derived::Scalar, typename Derived::RealScalar>::value), const Eigen::ScaledProduct<Derived> >::type Eigen::operator*(const Eigen::ProductBase<Derived, _Lhs, _Rhs>&, const typename Derived::RealScalar&)’
#   216 | operator*(const ProductBase<Derived,Lhs,Rhs>& prod, const typename Derived::RealScalar& x)
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/ProductBase.h:216:1: note:   template argument deduction/substitution failed:
# In file included from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# ./phys/units/quantity.hpp:136:48: note:   mismatched types ‘const Eigen::ProductBase<Derived, _Lhs, _Rhs>’ and ‘double’
#   136 | using PromoteMul = decltype( std::declval<X>() * std::declval<Y>() );
#       |                              ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:322,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/ProductBase.h:222:1: note: candidate: ‘template<class Derived, class Lhs, class Rhs> const Eigen::ScaledProduct<Derived> Eigen::operator*(const typename Derived::Scalar&, const Eigen::ProductBase<Derived, _Lhs, _Rhs>&)’
#   222 | operator*(const typename Derived::Scalar& x,const ProductBase<Derived,Lhs,Rhs>& prod)
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/ProductBase.h:222:1: note:   template argument deduction/substitution failed:
# In file included from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# ./phys/units/quantity.hpp:136:48: note:   ‘Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>’ is not derived from ‘const Eigen::ProductBase<Derived, _Lhs, _Rhs>’
#   136 | using PromoteMul = decltype( std::declval<X>() * std::declval<Y>() );
#       |                              ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:322,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/ProductBase.h:228:1: note: candidate: ‘template<class Derived, class Lhs, class Rhs> typename Eigen::internal::enable_if<(! Eigen::internal::is_same<typename Derived::Scalar, typename Derived::RealScalar>::value), const Eigen::ScaledProduct<Derived> >::type Eigen::operator*(const typename Derived::RealScalar&, const Eigen::ProductBase<Derived, _Lhs, _Rhs>&)’
#   228 | operator*(const typename Derived::RealScalar& x,const ProductBase<Derived,Lhs,Rhs>& prod)
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/ProductBase.h:228:1: note:   template argument deduction/substitution failed:
# In file included from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# ./phys/units/quantity.hpp:136:48: note:   ‘Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>’ is not derived from ‘const Eigen::ProductBase<Derived, _Lhs, _Rhs>’
#   136 | using PromoteMul = decltype( std::declval<X>() * std::declval<Y>() );
#       |                              ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Householder:17,
#                  from /opt/miniconda3/include/eigen3/Eigen/QR:10,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:4,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Householder/HouseholderSequence.h:409:99: note: candidate: ‘template<class OtherDerived, class VectorsType, class CoeffsType, int Side> typename Eigen::internal::matrix_type_times_scalar_type<typename VectorsType::Scalar, OtherDerived>::Type Eigen::operator*(const Eigen::MatrixBase<Derived>&, const Eigen::HouseholderSequence<VectorsType, CoeffsType, Side>&)’
#   409 | calar_type<typename VectorsType::Scalar,OtherDerived>::Type operator*(const MatrixBase<OtherDerived>& other, const HouseholderSequence<VectorsType,CoeffsType,Side>& h)
#       |                                                             ^~~~~~~~
#
# /opt/miniconda3/include/eigen3/Eigen/src/Householder/HouseholderSequence.h:409:99: note:   template argument deduction/substitution failed:
# In file included from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# ./phys/units/quantity.hpp:136:48: note:   mismatched types ‘const Eigen::MatrixBase<Derived>’ and ‘double’
#   136 | using PromoteMul = decltype( std::declval<X>() * std::declval<Y>() );
#       |                              ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/src/Core/MatrixBase.h:136,
#                  from /opt/miniconda3/include/eigen3/Eigen/Core:279,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/../plugins/CommonCwiseUnaryOps.h:80:1: note: candidate: ‘const Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple2_op<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, std::complex<phys::units::quantity<phys::units::dimensions<1, 0, -1> > > >, const Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1> > Eigen::operator*(const std::complex<phys::units::quantity<phys::units::dimensions<1, 0, -1> > >&, const StorageBaseType&)’
#    80 | operator*(const std::complex<Scalar>& scalar, const StorageBaseType& matrix)
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/../plugins/CommonCwiseUnaryOps.h:80:39: note:   no known conversion for argument 1 from ‘double’ to ‘const std::complex<phys::units::quantity<phys::units::dimensions<1, 0, -1> > >&’
#    80 | operator*(const std::complex<Scalar>& scalar, const StorageBaseType& matrix)
#       |           ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/../plugins/CommonCwiseUnaryOps.h:76:1: note: candidate: ‘const ScalarMultipleReturnType Eigen::operator*(const Scalar&, const StorageBaseType&)’
#    76 | operator*(const Scalar& scalar, const StorageBaseType& matrix)
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/../plugins/CommonCwiseUnaryOps.h:76:25: note:   no known conversion for argument 1 from ‘double’ to ‘const Scalar&’ {aka ‘const phys::units::quantity<phys::units::dimensions<1, 0, -1> >&’}
#    76 | operator*(const Scalar& scalar, const StorageBaseType& matrix)
#       |           ~~~~~~~~~~~~~~^~~~~~
# In file included from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# ./phys/units/quantity.hpp:559:1: note: candidate: ‘template<class D, class X, class Y> constexpr phys::units::quantity<D, decltype ((declval<X>() * declval<Y>()))> phys::units::operator*(const X&, const phys::units::quantity<D, Y>&)’
#   559 | operator*( X const & x, quantity<D, Y> const & y )
#       | ^~~~~~~~
# ./phys/units/quantity.hpp:559:1: note:   template argument deduction/substitution failed:
# tmp.remaining-issues.cpp:13:27: note:   ‘Speed3d’ {aka ‘Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>’} is not derived from ‘const phys::units::quantity<D, Y>’
#    13 |   Momentum3d momentum = m*speed ;
#       |                           ^~~~~
# In file included from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# ./phys/units/quantity.hpp:568:1: note: candidate: ‘template<class DX, class DY, class X, class Y> constexpr phys::units::detail::Product<DX, DY, X, Y> phys::units::operator*(const phys::units::quantity<D, Y>&, const phys::units::quantity<DY, Y>&)’
#   568 | operator*( quantity<DX, X> const & lhs, quantity< DY, Y > const & rhs )
#       | ^~~~~~~~
# ./phys/units/quantity.hpp:568:1: note:   template argument deduction/substitution failed:
# tmp.remaining-issues.cpp:13:27: note:   ‘Speed3d’ {aka ‘Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>’} is not derived from ‘const phys::units::quantity<DY, Y>’
#    13 |   Momentum3d momentum = m*speed ;
#       |                           ^~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:313,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/PermutationMatrix.h:539:1: note: candidate: ‘template<class Derived, class PermutationDerived> const Eigen::internal::permut_matrix_product_retval<PermutationDerived, Derived, 2> Eigen::operator*(const Eigen::MatrixBase<Derived>&, const Eigen::PermutationBase<PermutationDerived>&)’
#   539 | operator*(const MatrixBase<Derived>& matrix,
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/PermutationMatrix.h:539:1: note:   template argument deduction/substitution failed:
# tmp.remaining-issues.cpp:13:27: note:   ‘const phys::units::quantity<phys::units::dimensions<0, 1, 0, 0, 0, 0, 0> >’ is not derived from ‘const Eigen::MatrixBase<Derived>’
#    13 |   Momentum3d momentum = m*speed ;
#       |                           ^~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:313,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/PermutationMatrix.h:552:1: note: candidate: ‘template<class Derived, class PermutationDerived> const Eigen::internal::permut_matrix_product_retval<PermutationDerived, Derived, 1> Eigen::operator*(const Eigen::PermutationBase<PermutationDerived>&, const Eigen::MatrixBase<Derived>&)’
#   552 | operator*(const PermutationBase<PermutationDerived> &permutation,
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/PermutationMatrix.h:552:1: note:   template argument deduction/substitution failed:
# tmp.remaining-issues.cpp:13:27: note:   ‘const phys::units::quantity<phys::units::dimensions<0, 1, 0, 0, 0, 0, 0> >’ is not derived from ‘const Eigen::PermutationBase<PermutationDerived>’
#    13 |   Momentum3d momentum = m*speed ;
#       |                           ^~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:314,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/Transpositions.h:331:1: note: candidate: ‘template<class Derived, class TranspositionsDerived> const Eigen::internal::transposition_matrix_product_retval<TranspositionsDerived, Derived, 2> Eigen::operator*(const Eigen::MatrixBase<Derived>&, const Eigen::TranspositionsBase<TranspositionsDerived>&)’
#   331 | operator*(const MatrixBase<Derived>& matrix,
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/Transpositions.h:331:1: note:   template argument deduction/substitution failed:
# tmp.remaining-issues.cpp:13:27: note:   ‘const phys::units::quantity<phys::units::dimensions<0, 1, 0, 0, 0, 0, 0> >’ is not derived from ‘const Eigen::MatrixBase<Derived>’
#    13 |   Momentum3d momentum = m*speed ;
#       |                           ^~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:314,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/Transpositions.h:344:1: note: candidate: ‘template<class Derived, class TranspositionDerived> const Eigen::internal::transposition_matrix_product_retval<TranspositionDerived, Derived, 1> Eigen::operator*(const Eigen::TranspositionsBase<TranspositionsDerived>&, const Eigen::MatrixBase<Derived>&)’
#   344 | operator*(const TranspositionsBase<TranspositionDerived> &transpositions,
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/Transpositions.h:344:1: note:   template argument deduction/substitution failed:
# tmp.remaining-issues.cpp:13:27: note:   ‘const phys::units::quantity<phys::units::dimensions<0, 1, 0, 0, 0, 0, 0> >’ is not derived from ‘const Eigen::TranspositionsBase<TranspositionsDerived>’
#    13 |   Momentum3d momentum = m*speed ;
#       |                           ^~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:322,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/ProductBase.h:210:1: note: candidate: ‘template<class Derived, class Lhs, class Rhs> const Eigen::ScaledProduct<Derived> Eigen::operator*(const Eigen::ProductBase<Derived, _Lhs, _Rhs>&, const typename Derived::Scalar&)’
#   210 | operator*(const ProductBase<Derived,Lhs,Rhs>& prod, const typename Derived::Scalar& x)
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/ProductBase.h:210:1: note:   template argument deduction/substitution failed:
# tmp.remaining-issues.cpp:13:27: note:   ‘const phys::units::quantity<phys::units::dimensions<0, 1, 0, 0, 0, 0, 0> >’ is not derived from ‘const Eigen::ProductBase<Derived, _Lhs, _Rhs>’
#    13 |   Momentum3d momentum = m*speed ;
#       |                           ^~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:322,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/ProductBase.h:216:1: note: candidate: ‘template<class Derived, class Lhs, class Rhs> typename Eigen::internal::enable_if<(! Eigen::internal::is_same<typename Derived::Scalar, typename Derived::RealScalar>::value), const Eigen::ScaledProduct<Derived> >::type Eigen::operator*(const Eigen::ProductBase<Derived, _Lhs, _Rhs>&, const typename Derived::RealScalar&)’
#   216 | operator*(const ProductBase<Derived,Lhs,Rhs>& prod, const typename Derived::RealScalar& x)
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/ProductBase.h:216:1: note:   template argument deduction/substitution failed:
# tmp.remaining-issues.cpp:13:27: note:   ‘const phys::units::quantity<phys::units::dimensions<0, 1, 0, 0, 0, 0, 0> >’ is not derived from ‘const Eigen::ProductBase<Derived, _Lhs, _Rhs>’
#    13 |   Momentum3d momentum = m*speed ;
#       |                           ^~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:322,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/ProductBase.h:222:1: note: candidate: ‘template<class Derived, class Lhs, class Rhs> const Eigen::ScaledProduct<Derived> Eigen::operator*(const typename Derived::Scalar&, const Eigen::ProductBase<Derived, _Lhs, _Rhs>&)’
#   222 | operator*(const typename Derived::Scalar& x,const ProductBase<Derived,Lhs,Rhs>& prod)
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/ProductBase.h:222:1: note:   template argument deduction/substitution failed:
# tmp.remaining-issues.cpp:13:27: note:   ‘Speed3d’ {aka ‘Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>’} is not derived from ‘const Eigen::ProductBase<Derived, _Lhs, _Rhs>’
#    13 |   Momentum3d momentum = m*speed ;
#       |                           ^~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:322,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/ProductBase.h:228:1: note: candidate: ‘template<class Derived, class Lhs, class Rhs> typename Eigen::internal::enable_if<(! Eigen::internal::is_same<typename Derived::Scalar, typename Derived::RealScalar>::value), const Eigen::ScaledProduct<Derived> >::type Eigen::operator*(const typename Derived::RealScalar&, const Eigen::ProductBase<Derived, _Lhs, _Rhs>&)’
#   228 | operator*(const typename Derived::RealScalar& x,const ProductBase<Derived,Lhs,Rhs>& prod)
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/ProductBase.h:228:1: note:   template argument deduction/substitution failed:
# tmp.remaining-issues.cpp:13:27: note:   ‘Speed3d’ {aka ‘Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>’} is not derived from ‘const Eigen::ProductBase<Derived, _Lhs, _Rhs>’
#    13 |   Momentum3d momentum = m*speed ;
#       |                           ^~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Householder:17,
#                  from /opt/miniconda3/include/eigen3/Eigen/QR:10,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:4,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Householder/HouseholderSequence.h:409:99: note: candidate: ‘template<class OtherDerived, class VectorsType, class CoeffsType, int Side> typename Eigen::internal::matrix_type_times_scalar_type<typename VectorsType::Scalar, OtherDerived>::Type Eigen::operator*(const Eigen::MatrixBase<Derived>&, const Eigen::HouseholderSequence<VectorsType, CoeffsType, Side>&)’
#   409 | calar_type<typename VectorsType::Scalar,OtherDerived>::Type operator*(const MatrixBase<OtherDerived>& other, const HouseholderSequence<VectorsType,CoeffsType,Side>& h)
#       |                                                             ^~~~~~~~
#
# /opt/miniconda3/include/eigen3/Eigen/src/Householder/HouseholderSequence.h:409:99: note:   template argument deduction/substitution failed:
# tmp.remaining-issues.cpp:13:27: note:   ‘const phys::units::quantity<phys::units::dimensions<0, 1, 0, 0, 0, 0, 0> >’ is not derived from ‘const Eigen::MatrixBase<Derived>’
#    13 |   Momentum3d momentum = m*speed ;
#       |                           ^~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/src/Core/MatrixBase.h:136,
#                  from /opt/miniconda3/include/eigen3/Eigen/Core:279,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/../plugins/CommonCwiseUnaryOps.h:80:1: note: candidate: ‘const Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple2_op<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, std::complex<phys::units::quantity<phys::units::dimensions<1, 0, -1> > > >, const Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1> > Eigen::operator*(const std::complex<phys::units::quantity<phys::units::dimensions<1, 0, -1> > >&, const StorageBaseType&)’
#    80 | operator*(const std::complex<Scalar>& scalar, const StorageBaseType& matrix)
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/../plugins/CommonCwiseUnaryOps.h:80:39: note:   no known conversion for argument 1 from ‘const phys::units::quantity<phys::units::dimensions<0, 1, 0, 0, 0, 0, 0> >’ to ‘const std::complex<phys::units::quantity<phys::units::dimensions<1, 0, -1> > >&’
#    80 | operator*(const std::complex<Scalar>& scalar, const StorageBaseType& matrix)
#       |           ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/../plugins/CommonCwiseUnaryOps.h:76:1: note: candidate: ‘const ScalarMultipleReturnType Eigen::operator*(const Scalar&, const StorageBaseType&)’
#    76 | operator*(const Scalar& scalar, const StorageBaseType& matrix)
#       | ^~~~~~~~
# /opt/miniconda3/include/eigen3/Eigen/src/Core/../plugins/CommonCwiseUnaryOps.h:76:25: note:   no known conversion for argument 1 from ‘const phys::units::quantity<phys::units::dimensions<0, 1, 0, 0, 0, 0, 0> >’ to ‘const Scalar&’ {aka ‘const phys::units::quantity<phys::units::dimensions<1, 0, -1> >&’}
#    76 | operator*(const Scalar& scalar, const StorageBaseType& matrix)
#       |           ~~~~~~~~~~~~~~^~~~~~
# tmp.remaining-issues.cpp:14:46: error: conversion from ‘quantity<dimensions<2,2,-2,[...],[...],[...],[...]>,[...]>’ to non-scalar type ‘quantity<dimensions<1,1,-1,[...],[...],[...],[...]>,[...]>’ requested
#    14 |   Momentum p = momentum.norm()*kilogram*meter/second ;
#       |                ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:301,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/Dot.h: In instantiation of ‘typename Eigen::NumTraits<typename Eigen::internal::traits<T>::Scalar>::Real Eigen::MatrixBase<Derived>::norm() const [with Derived = Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 1, -1> >, 3, 1>; typename Eigen::NumTraits<typename Eigen::internal::traits<T>::Scalar>::Real = phys::units::quantity<phys::units::dimensions<1, 1, -1> >; typename Eigen::internal::traits<T>::Scalar = phys::units::quantity<phys::units::dimensions<1, 1, -1> >]’:
# tmp.remaining-issues.cpp:14:29:   required from here
# /opt/miniconda3/include/eigen3/Eigen/src/Core/Dot.h:128:14: error: could not convert ‘phys::units::sqrt<phys::units::dimensions<1, 1, -1>, double>(((const Eigen::MatrixBase<Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 1, -1> >, 3, 1> >*)this)->Eigen::MatrixBase<Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 1, -1> >, 3, 1> >::squaredNorm())’ from ‘phys::units::detail::Root<phys::units::dimensions<1, 1, -1>, 2, double>’ {aka ‘double’} to ‘Eigen::GenericNumTraits<phys::units::quantity<phys::units::dimensions<1, 1, -1> > >::Real’ {aka ‘phys::units::quantity<phys::units::dimensions<1, 1, -1> >’}
#   128 |   return sqrt(squaredNorm());
#       |          ~~~~^~~~~~~~~~~~~~~
#       |              |
#       |              phys::units::detail::Root<phys::units::dimensions<1, 1, -1>, 2, double> {aka double}
# In file included from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# ./phys/units/quantity.hpp: In instantiation of ‘phys::units::detail::Root<D, 2, X> phys::units::sqrt(const phys::units::quantity<D, T>&) [with D = phys::units::dimensions<1, 1, -1>; X = double; phys::units::detail::Root<D, 2, X> = double]’:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/Dot.h:128:14:   required from ‘typename Eigen::NumTraits<typename Eigen::internal::traits<T>::Scalar>::Real Eigen::MatrixBase<Derived>::norm() const [with Derived = Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 1, -1> >, 3, 1>; typename Eigen::NumTraits<typename Eigen::internal::traits<T>::Scalar>::Real = phys::units::quantity<phys::units::dimensions<1, 1, -1> >; typename Eigen::internal::traits<T>::Scalar = phys::units::quantity<phys::units::dimensions<1, 1, -1> >]’
# tmp.remaining-issues.cpp:14:29:   required from here
# ./phys/units/quantity.hpp:672:31: error: static assertion failed: root result dimensions must be integral
#   672 |       detail::root<D, 2, X >::all_even_multiples, "root result dimensions must be integral" );
#       |                               ^~~~~~~~~~~~~~~~~~
# ./phys/units/quantity.hpp:672:31: note: ‘phys::units::detail::root<phys::units::dimensions<1, 1, -1>, 2, double>::all_even_multiples’ evaluates to false
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:318,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h: In instantiation of ‘std::ostream& Eigen::internal::print_matrix(std::ostream&, const Derived&, const Eigen::IOFormat&) [with Derived = Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>; std::ostream = std::basic_ostream<char>]’:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:245:32:   required from ‘std::ostream& Eigen::operator<<(std::ostream&, const Eigen::DenseBase<Derived>&) [with Derived = Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>; std::ostream = std::basic_ostream<char>]’
# tmp.remaining-issues.cpp:16:16:   required from here
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:200:14: error: no match for ‘operator<<’ (operand types are ‘std::stringstream’ {aka ‘std::__cxx11::basic_stringstream<char>’} and ‘const Scalar’ {aka ‘const phys::units::quantity<phys::units::dimensions<1, 0, -1> >’})
#   200 |         sstr << m.coeff(i,j);
#       |         ~~~~~^~~~~~~~~~~~~~~
# In file included from /usr/local/include/c++/11.2.0/iostream:39,
#                  from tmp.remaining-issues.h:2,
#                  from tmp.remaining-issues.cpp:2:
# /usr/local/include/c++/11.2.0/ostream:108:7: note: candidate: ‘std::basic_ostream<_CharT, _Traits>::__ostream_type& std::basic_ostream<_CharT, _Traits>::operator<<(std::basic_ostream<_CharT, _Traits>::__ostream_type& (*)(std::basic_ostream<_CharT, _Traits>::__ostream_type&)) [with _CharT = char; _Traits = std::char_traits<char>; std::basic_ostream<_CharT, _Traits>::__ostream_type = std::basic_ostream<char>]’
#   108 |       operator<<(__ostream_type& (*__pf)(__ostream_type&))
#       |       ^~~~~~~~
# /usr/local/include/c++/11.2.0/ostream:108:36: note:   no known conversion for argument 1 from ‘const Scalar’ {aka ‘const phys::units::quantity<phys::units::dimensions<1, 0, -1> >’} to ‘std::basic_ostream<char>::__ostream_type& (*)(std::basic_ostream<char>::__ostream_type&)’ {aka ‘std::basic_ostream<char>& (*)(std::basic_ostream<char>&)’}
# ...
# ./phys/units/quantity.hpp:346:24: note: declared private here
#   346 |     constexpr explicit quantity( value_type x ) : m_value{ x } { }
#       |                        ^~~~~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:318,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h: In instantiation of ‘static int Eigen::internal::significant_decimals_default_impl<Scalar, IsInteger>::run() [with Scalar = phys::units::quantity<phys::units::dimensions<1, 0, -1> >; bool IsInteger = false]’:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:180:66:   required from ‘std::ostream& Eigen::internal::print_matrix(std::ostream&, const Derived&, const Eigen::IOFormat&) [with Derived = Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>; std::ostream = std::basic_ostream<char>]’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:245:32:   required from ‘std::ostream& Eigen::operator<<(std::ostream&, const Eigen::DenseBase<Derived>&) [with Derived = Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>; std::ostream = std::basic_ostream<char>]’
# tmp.remaining-issues.cpp:16:16:   required from here
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:132:42: error: no matching function for call to ‘log(Eigen::GenericNumTraits<phys::units::quantity<phys::units::dimensions<1, 0, -1> > >::Real)’
#   132 |     return cast<RealScalar,int>(ceil(-log(NumTraits<RealScalar>::epsilon())/log(RealScalar(10))));
#       |                                       ~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:28,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /usr/local/include/c++/11.2.0/complex:820:5: note: candidate: ‘template<class _Tp> std::complex<_Tp> std::log(const std::complex<_Tp>&)’
#   820 |     log(const complex<_Tp>& __z) { return __complex_log(__z.__rep()); }
#       |     ^~~
# /usr/local/include/c++/11.2.0/complex:820:5: note:   template argument deduction/substitution failed:
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:318,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:132:42: note:   ‘Eigen::GenericNumTraits<phys::units::quantity<phys::units::dimensions<1, 0, -1> > >::Real’ {aka ‘phys::units::quantity<phys::units::dimensions<1, 0, -1> >’} is not derived from ‘const std::complex<_Tp>’
#   132 |     return cast<RealScalar,int>(ceil(-log(NumTraits<RealScalar>::epsilon())/log(RealScalar(10))));
#       |                                       ~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ./phys/units/quantity.hpp:32,
#                  from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# /usr/local/include/c++/11.2.0/cmath:350:5: note: candidate: ‘template<class _Tp> constexpr typename __gnu_cxx::__enable_if<std::__is_integer<_Tp>::__value, double>::__type std::log(_Tp)’
#   350 |     log(_Tp __x)
#       |     ^~~
# /usr/local/include/c++/11.2.0/cmath:350:5: note:   template argument deduction/substitution failed:
# /usr/local/include/c++/11.2.0/cmath: In substitution of ‘template<class _Tp> constexpr typename __gnu_cxx::__enable_if<std::__is_integer<_Tp>::__value, double>::__type std::log(_Tp) [with _Tp = phys::units::quantity<phys::units::dimensions<1, 0, -1> >]’:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:132:42:   required from ‘static int Eigen::internal::significant_decimals_default_impl<Scalar, IsInteger>::run() [with Scalar = phys::units::quantity<phys::units::dimensions<1, 0, -1> >; bool IsInteger = false]’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:180:66:   required from ‘std::ostream& Eigen::internal::print_matrix(std::ostream&, const Derived&, const Eigen::IOFormat&) [with Derived = Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>; std::ostream = std::basic_ostream<char>]’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:245:32:   required from ‘std::ostream& Eigen::operator<<(std::ostream&, const Eigen::DenseBase<Derived>&) [with Derived = Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>; std::ostream = std::basic_ostream<char>]’
# tmp.remaining-issues.cpp:16:16:   required from here
# /usr/local/include/c++/11.2.0/cmath:350:5: error: no type named ‘__type’ in ‘struct __gnu_cxx::__enable_if<false, double>’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h: In instantiation of ‘static int Eigen::internal::significant_decimals_default_impl<Scalar, IsInteger>::run() [with Scalar = phys::units::quantity<phys::units::dimensions<1, 0, -1> >; bool IsInteger = false]’:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:180:66:   required from ‘std::ostream& Eigen::internal::print_matrix(std::ostream&, const Derived&, const Eigen::IOFormat&) [with Derived = Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>; std::ostream = std::basic_ostream<char>]’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:245:32:   required from ‘std::ostream& Eigen::operator<<(std::ostream&, const Eigen::DenseBase<Derived>&) [with Derived = Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>; std::ostream = std::basic_ostream<char>]’
# tmp.remaining-issues.cpp:16:16:   required from here
# /usr/local/include/c++/11.2.0/cmath:342:3: note: candidate: ‘constexpr long double std::log(long double)’
#   342 |   log(long double __x)
#       |   ^~~
# /usr/local/include/c++/11.2.0/cmath:342:19: note:   no known conversion for argument 1 from ‘Eigen::GenericNumTraits<phys::units::quantity<phys::units::dimensions<1, 0, -1> > >::Real’ {aka ‘phys::units::quantity<phys::units::dimensions<1, 0, -1> >’} to ‘long double’
#   342 |   log(long double __x)
#       |       ~~~~~~~~~~~~^~~
# /usr/local/include/c++/11.2.0/cmath:338:3: note: candidate: ‘constexpr float std::log(float)’
#   338 |   log(float __x)
#       |   ^~~
# /usr/local/include/c++/11.2.0/cmath:338:13: note:   no known conversion for argument 1 from ‘Eigen::GenericNumTraits<phys::units::quantity<phys::units::dimensions<1, 0, -1> > >::Real’ {aka ‘phys::units::quantity<phys::units::dimensions<1, 0, -1> >’} to ‘float’
#   338 |   log(float __x)
#       |       ~~~~~~^~~
# In file included from /usr/include/features.h:461,
#                  from /usr/local/include/c++/11.2.0/x86_64-linux-gnu/bits/os_defines.h:39,
#                  from /usr/local/include/c++/11.2.0/x86_64-linux-gnu/bits/c++config.h:586,
#                  from /usr/local/include/c++/11.2.0/iostream:38,
#                  from tmp.remaining-issues.h:2,
#                  from tmp.remaining-issues.cpp:2:
# /usr/include/x86_64-linux-gnu/bits/mathcalls.h:104:1: note: candidate: ‘double log(double)’
#   104 | __MATHCALL_VEC (log,, (_Mdouble_ __x));
#       | ^~~~~~~~~~~~~~
# In file included from /usr/local/include/c++/11.2.0/cmath:45,
#                  from ./phys/units/quantity.hpp:32,
#                  from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# /usr/include/x86_64-linux-gnu/bits/mathcalls.h:104:1: note:   no known conversion for argument 1 from ‘Eigen::GenericNumTraits<phys::units::quantity<phys::units::dimensions<1, 0, -1> > >::Real’ {aka ‘phys::units::quantity<phys::units::dimensions<1, 0, -1> >’} to ‘double’
#   104 | __MATHCALL_VEC (log,, (_Mdouble_ __x));
#       | ^
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:318,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:132:81: error: ‘constexpr phys::units::quantity<Dims, T>::quantity(phys::units::quantity<Dims, T>::value_type) [with Dims = phys::units::dimensions<1, 0, -1>; T = double; phys::units::quantity<Dims, T>::value_type = double]’ is private within this context
#   132 | Scalar,int>(ceil(-log(NumTraits<RealScalar>::epsilon())/log(RealScalar(10))));
#       |                                                             ^~~~~~~~~~~~~~
#
# In file included from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# ./phys/units/quantity.hpp:346:24: note: declared private here
#   346 |     constexpr explicit quantity( value_type x ) : m_value{ x } { }
#       |                        ^~~~~~~~
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:318,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:132:80: error: no matching function for call to ‘log(Eigen::internal::significant_decimals_default_impl<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, false>::RealScalar)’
#   132 | lScalar,int>(ceil(-log(NumTraits<RealScalar>::epsilon())/log(RealScalar(10))));
#       |                                                          ~~~^~~~~~~~~~~~~~~~
#
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:28,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /usr/local/include/c++/11.2.0/complex:820:5: note: candidate: ‘template<class _Tp> std::complex<_Tp> std::log(const std::complex<_Tp>&)’
#   820 |     log(const complex<_Tp>& __z) { return __complex_log(__z.__rep()); }
#       |     ^~~
# /usr/local/include/c++/11.2.0/complex:820:5: note:   template argument deduction/substitution failed:
# In file included from /opt/miniconda3/include/eigen3/Eigen/Core:318,
#                  from /opt/miniconda3/include/eigen3/Eigen/Dense:1,
#                  from tmp.remaining-issues.h:6,
#                  from tmp.remaining-issues.cpp:2:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:132:80: note:   ‘Eigen::internal::significant_decimals_default_impl<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, false>::RealScalar’ {aka ‘phys::units::quantity<phys::units::dimensions<1, 0, -1> >’} is not derived from ‘const std::complex<_Tp>’
#   132 | lScalar,int>(ceil(-log(NumTraits<RealScalar>::epsilon())/log(RealScalar(10))));
#       |                                                          ~~~^~~~~~~~~~~~~~~~
#
# In file included from ./phys/units/quantity.hpp:32,
#                  from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# /usr/local/include/c++/11.2.0/cmath:350:5: note: candidate: ‘template<class _Tp> constexpr typename __gnu_cxx::__enable_if<std::__is_integer<_Tp>::__value, double>::__type std::log(_Tp)’
#   350 |     log(_Tp __x)
#       |     ^~~
# /usr/local/include/c++/11.2.0/cmath:350:5: note:   template argument deduction/substitution failed:
# /usr/local/include/c++/11.2.0/cmath: In substitution of ‘template<class _Tp> constexpr typename __gnu_cxx::__enable_if<std::__is_integer<_Tp>::__value, double>::__type std::log(_Tp) [with _Tp = phys::units::quantity<phys::units::dimensions<1, 0, -1> >]’:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:132:80:   required from ‘static int Eigen::internal::significant_decimals_default_impl<Scalar, IsInteger>::run() [with Scalar = phys::units::quantity<phys::units::dimensions<1, 0, -1> >; bool IsInteger = false]’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:180:66:   required from ‘std::ostream& Eigen::internal::print_matrix(std::ostream&, const Derived&, const Eigen::IOFormat&) [with Derived = Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>; std::ostream = std::basic_ostream<char>]’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:245:32:   required from ‘std::ostream& Eigen::operator<<(std::ostream&, const Eigen::DenseBase<Derived>&) [with Derived = Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>; std::ostream = std::basic_ostream<char>]’
# tmp.remaining-issues.cpp:16:16:   required from here
# /usr/local/include/c++/11.2.0/cmath:350:5: error: no type named ‘__type’ in ‘struct __gnu_cxx::__enable_if<false, double>’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h: In instantiation of ‘static int Eigen::internal::significant_decimals_default_impl<Scalar, IsInteger>::run() [with Scalar = phys::units::quantity<phys::units::dimensions<1, 0, -1> >; bool IsInteger = false]’:
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:180:66:   required from ‘std::ostream& Eigen::internal::print_matrix(std::ostream&, const Derived&, const Eigen::IOFormat&) [with Derived = Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>; std::ostream = std::basic_ostream<char>]’
# /opt/miniconda3/include/eigen3/Eigen/src/Core/IO.h:245:32:   required from ‘std::ostream& Eigen::operator<<(std::ostream&, const Eigen::DenseBase<Derived>&) [with Derived = Eigen::Matrix<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, 3, 1>; std::ostream = std::basic_ostream<char>]’
# tmp.remaining-issues.cpp:16:16:   required from here
# /usr/local/include/c++/11.2.0/cmath:342:3: note: candidate: ‘constexpr long double std::log(long double)’
#   342 |   log(long double __x)
#       |   ^~~
# /usr/local/include/c++/11.2.0/cmath:342:19: note:   no known conversion for argument 1 from ‘Eigen::internal::significant_decimals_default_impl<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, false>::RealScalar’ {aka ‘phys::units::quantity<phys::units::dimensions<1, 0, -1> >’} to ‘long double’
#   342 |   log(long double __x)
#       |       ~~~~~~~~~~~~^~~
# /usr/local/include/c++/11.2.0/cmath:338:3: note: candidate: ‘constexpr float std::log(float)’
#   338 |   log(float __x)
#       |   ^~~
# /usr/local/include/c++/11.2.0/cmath:338:13: note:   no known conversion for argument 1 from ‘Eigen::internal::significant_decimals_default_impl<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, false>::RealScalar’ {aka ‘phys::units::quantity<phys::units::dimensions<1, 0, -1> >’} to ‘float’
#   338 |   log(float __x)
#       |       ~~~~~~^~~
# In file included from /usr/include/features.h:461,
#                  from /usr/local/include/c++/11.2.0/x86_64-linux-gnu/bits/os_defines.h:39,
#                  from /usr/local/include/c++/11.2.0/x86_64-linux-gnu/bits/c++config.h:586,
#                  from /usr/local/include/c++/11.2.0/iostream:38,
#                  from tmp.remaining-issues.h:2,
#                  from tmp.remaining-issues.cpp:2:
# /usr/include/x86_64-linux-gnu/bits/mathcalls.h:104:1: note: candidate: ‘double log(double)’
#   104 | __MATHCALL_VEC (log,, (_Mdouble_ __x));
#       | ^~~~~~~~~~~~~~
# In file included from /usr/local/include/c++/11.2.0/cmath:45,
#                  from ./phys/units/quantity.hpp:32,
#                  from ./phys/units/quantity_io.hpp:25,
#                  from phys/units/io.hpp:19,
#                  from tmp.remaining-issues.h:4,
#                  from tmp.remaining-issues.cpp:2:
# /usr/include/x86_64-linux-gnu/bits/mathcalls.h:104:1: note:   no known conversion for argument 1 from ‘Eigen::internal::significant_decimals_default_impl<phys::units::quantity<phys::units::dimensions<1, 0, -1> >, false>::RealScalar’ {aka ‘phys::units::quantity<phys::units::dimensions<1, 0, -1> >’} to ‘double’
#   104 | __MATHCALL_VEC (log,, (_Mdouble_ __x));
#       | ^

# %% [markdown]
# Actually, Eigen does not accept to multiply a scalar with a vector if all the numbers are not expressed in the same types : **strong typing is not compatible with popular linear algebra libraries**.

# %% [markdown]
# Is there an easy way to convert the variables back into builtin numerical types before using such library ? And put them back into physical units afterward ?

# %% [markdown]
# Can we setup some sort of code generation, and use physical units during development, together with a strongly typed avatar of eigen, then move back to builtin types and Eigen for production ? **Not an easy way !**

# %% [markdown]
# ## Also...

# %% [markdown]
# **I/O** : When handling very large data sets, how to add the lacking units afterwards ? How to store the data with their units efficiently ?

# %% [markdown]
# **Compilation time**: provided there exists a units-friendly linear algebra library, what will be the compilation time, if  every `Vector/Matrix` must be instanciated with all the possible physical units used in the program... And let's speak about the compilation error messages...

# %% [markdown]
# ## In the end
#
# Until there exists some linear algebra library which is compatible with strong types, do not throw the baby out with the bathwater:
# * use strong types for integers: index, sizes, identifiers, ... ;
# * rely on user-defined literals for the handling of physical units multipliers ;
# * use physical units in code areas which do not require some incompatible external library ;
# * select reference storage units at the right scale for your problem.

# %% [markdown]
# # Questions ?

# %% [markdown]
# © *CNRS 2020*
# *Assemblée et rédigée par David Chamont, cette œuvre est mise à disposition selon les termes de la [Licence Creative Commons - Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International](http://creativecommons.org/licenses/by-nc-sa/4.0/)*
